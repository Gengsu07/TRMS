# %%
import pandas as pd
import streamlit as st 
conn = st.experimental_connection("ppmpkm", type="sql")
from scripts.db import (
    data_ket,
    target,
    sektor,
    klu,
    sektor_yoy,
    jns_pajak,
    kjs,
    kpi,
    linedata,
    naikturun,
    proporsi,
    cluster,
    data_sankey,
    generate_rgba_colors,
    top10kpp,
    sektor_yoy,
    growth_month,
    subsektor,
    sankey_subsektor,
    generate_rgba_colors,
    explore_data,
)

# %%
filter = '''"DATEBAYAR">='2023-01-01' and"DATEBAYAR"<='2023-07-09' '''
filter22 = ''' "DATEBAYAR">='2022-01-01' and"DATEBAYAR"<='2022-07-09' '''

# %%
data_sektor_awal = sektor_yoy(filter, filter22, includewp=False)
# data_sektor = data_sektor_awal[0]
sektor_mom = data_sektor_awal[1]
sektor_mom = sektor_mom[["NM_KATEGORI", "BULANBAYAR", "BRUTO2023"]]
sektor_mom = sektor_mom[sektor_mom["NM_KATEGORI"] != ""]
sektor_mom.fillna(0, inplace=True)
sektor_mom = sektor_mom.groupby(["NM_KATEGORI", "BULANBAYAR"]).sum().reset_index()
# sektor_mom.sort_values(by="BULANBAYAR", ascending=True, inplace=True)

sektor_mom
# Out:
# 2023-07-09 21:13:37.735 No runtime found, using MemoryCacheStorageManager
#                               NM_KATEGORI  BULANBAYAR     BRUTO2023
# 0    ADMIN. PEMERINTAHAN & JAMINAN SOSIAL           1  7.677392e+10
# 1    ADMIN. PEMERINTAHAN & JAMINAN SOSIAL           2  1.148359e+11
# 2    ADMIN. PEMERINTAHAN & JAMINAN SOSIAL           3  1.549767e+11
# 3    ADMIN. PEMERINTAHAN & JAMINAN SOSIAL           4  2.648945e+11
# 4    ADMIN. PEMERINTAHAN & JAMINAN SOSIAL           5  1.985832e+11
# ..                                    ...         ...           ...
# 149                  TREATMENT AIR,LIMBAH           3  3.524871e+09
# 150                  TREATMENT AIR,LIMBAH           4  1.794939e+09
# 151                  TREATMENT AIR,LIMBAH           5  4.940407e+09
# 152                  TREATMENT AIR,LIMBAH           6  8.947653e+08
# 153                  TREATMENT AIR,LIMBAH           7  0.000000e+00
#
# [154 rows x 3 columns]
